# %%
import pandas as pd 
lookup_cluster = pd.read_csv('lookup.csv')
currentCell = '12:15'
current_cluster = int(lookup_cluster[lookup_cluster['cell'] == currentCell]['cluster'])
current_cluster
# Out:
# 13

# %%
lookup_table = pd.read_csv('lookup_Mon.csv')
density = lookup_table['h12_density'][current_cluster]
density
# Out:
# 'low'

# %%
lookup_table
# Out:
#     cluster  h12_trip_rate h12_density h12_top_cell  h13_trip_rate  \
# 0         0      37.600000        high        27:77      37.483333
# 1         1       0.000000         low          NaN       0.000000
# 2         2       0.466667      median        50:90       0.500000
# 3         3       0.016667         low        30:26       0.033333
# 4         4       0.000000         low          NaN       0.000000
# 5         5     562.766667        high        26:64     571.066667
# 6         6       0.000000         low          NaN       0.000000
# 7         7       0.000000         low          NaN       0.016667
# 8         8       0.100000      median        63:49       0.100000
# 9         9       0.000000         low          NaN       0.000000
# 10       10      44.066667        high        41:50      45.466667
# 11       11       0.000000         low          NaN       0.000000
# 12       12       3.083333      median        72:59       4.333333
# ...

# %%
import pandas as pd
import datetime
datetime_object = datetime.datetime.now()

# %%
calendar.day_name(datetime_object)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-5d8910588fc7> in <module>()
# ----> 1 calendar.day_name(datetime_object)
#
# NameError: name 'calendar' is not defined
